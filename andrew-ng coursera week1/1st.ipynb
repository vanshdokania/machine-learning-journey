# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "C:/Users/vansh/.kaggle"

# %%
# !kaggle datasets download -d abdulmalik1518/cars-datasets-2025
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdulmalik1518/cars-datasets-2025
# License(s): apache-2.0
# ...
#   0%|          | 0.00/25.4k [00:00<?, ?B/s]
# 100%|██████████| 25.4k/25.4k [00:00<00:00, 11.6MB/s]

# %%
import os
print(os.path.exists("C:/Users/vansh/.kaggle/kaggle.json"))
# Out:
# True

# %%
# !kaggle datasets list
# Out:
# ref                                                               title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# abdulmalik1518/cars-datasets-2025                                 Cars Datasets (2025)                                     25987  2025-07-17 21:43:28.493000           3751         85  1.0
# sahilislam007/college-student-placement-factors-dataset           College Student Placement Factors Dataset               110450  2025-07-02 08:33:50.547000           7406        156  1.0
# divyaraj2006/netflix-tv-shows-and-movies                          NETFLIX TV SHOWS AND MOVIES                              34642  2025-07-04 01:47:30.347000           1126         25  1.0
# ...

# %%
import zipfile

with zipfile.ZipFile("cars-datasets-2025.zip", 'r') as zip_ref:
    zip_ref.extractall("data/cars")

import pandas as pd

df = pd.read_csv(r"D:\ml-linear regression\data\cars\Cars Datasets 2025.csv", encoding='latin1')

df.head()
# Out:
#   Company Names     Cars Names      Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE           V8             3990 cc     963 hp
# 1   ROLLS ROYCE        PHANTOM          V12             6749 cc     563 hp
# 2          Ford            KA+  1.2L Petrol            1,200 cc   70-85 hp
# 3      MERCEDES        GT 63 S           V8            3,982 cc     630 hp
# 4          AUDI     AUDI R8 Gt          V10            5,204 cc     602 hp
#
#   Total Speed Performance(0 - 100 )KM/H      Cars Prices       Fuel Types  \
# 0    340 km/h                   2.5 sec      $1,100,000   plug in hyrbrid
# 1    250 km/h                   5.3 sec        $460,000            Petrol
# 2    165 km/h                  10.5 sec  $12,000-$15,000           Petrol
# 3    250 km/h                   3.2 sec        $161,000            Petrol
# 4    320 km/h                   3.6 sec        $253,290            Petrol
#
#   Seats        Torque
# 0     2        800 Nm
# 1     5        900 Nm
# ...

# %%
# !kaggle datasets download -d ruchi798/data-science-job-salaries
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/7.37k [00:00<?, ?B/s]
# 100%|██████████| 7.37k/7.37k [00:00<00:00, 4.57MB/s]

# %%
with zipfile.ZipFile("data-science-job-salaries.zip", 'r') as zip_ref:
    zip_ref.extractall("data/salaries")


df = pd.read_csv(r"D:\ml-linear regression\data\salaries\ds_salaries.csv", encoding='latin1')

df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
# !kaggle datasets download -d codebreaker619/salary-data-with-age-and-experience
# Out:
# Dataset URL: https://www.kaggle.com/datasets/codebreaker619/salary-data-with-age-and-experience
# License(s): other
# ...
#   0%|          | 0.00/419 [00:00<?, ?B/s]
# 100%|██████████| 419/419 [00:00<00:00, 98.1kB/s]

# %%
with zipfile.ZipFile("salary-data-with-age-and-experience.zip", 'r') as zip_ref:
    zip_ref.extractall("data/salaries-with-exp")


df = pd.read_csv(r"D:\ml-linear regression\data\salaries-with-exp\Salary_Data.csv", encoding='latin1')

df.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
class Linear_regression():

    def __init__(self, alpha, number_of_iterations):
        
        self.alpha = alpha
        self.number_of_iterations = number_of_iterations


    def fit(self, X, Y):
        
        self.m , self.n = X.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.Y = Y

        for i in range (self.number_of_iterations):
            self.update_weights()

    def update_weights(self):

        Y_predict = self.predict(self.X)
        dw = -(2*(self.X.T).dot(self.Y - Y_predict)) / self.m
        db = -2*np.sum(self.Y - Y_predict) / self.m
        self.w = self.w - self.alpha*dw
        self.b = self.b - self.alpha*db


    def predict(self, X):
        return X.dot(self.w)+self.b

# %%
from sklearn.model_selection import train_test_split

# %%
salary_data = pd.read_csv(r'D:\ml-linear regression\data\salaries-with-exp\Salary_Data.csv')
salary_data.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
salary_data.tail()
# Out:
#     YearsExperience   Age  Salary
# 25              9.0  34.0  105582
# 26              9.5  35.0  116969
# 27              9.6  36.0  112635
# 28             10.3  37.0  122391
# 29             10.5  38.0  121872

# %%
salary_data.shape
# Out:
# (30, 3)

# %%
X = salary_data.iloc[:,:-1].values
Y = salary_data.iloc[:,2].values

# %%
print(X)
# Out:
# [[ 1.1 21. ]
#  [ 1.3 21.5]
#  [ 1.5 21.7]
#  [ 2.  22. ]
#  [ 2.2 22.2]
#  [ 2.9 23. ]
#  [ 3.  23. ]
#  [ 3.2 23.3]
#  [ 3.2 23.3]
#  [ 3.7 23.6]
#  [ 3.9 23.9]
#  [ 4.  24. ]
#  [ 4.  24. ]
#  [ 4.1 24. ]
#  [ 4.5 25. ]
#  [ 4.9 25. ]
#  [ 5.1 26. ]
#  [ 5.3 27. ]
#  [ 5.9 28. ]
#  [ 6.  29. ]
#  [ 6.8 30. ]
#  [ 7.1 30. ]
#  [ 7.9 31. ]
#  [ 8.2 32. ]
#  [ 8.7 33. ]
#  [ 9.  34. ]
#  [ 9.5 35. ]
#  [ 9.6 36. ]
#  [10.3 37. ]
#  [10.5 38. ]]

# %%
print(Y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.33, random_state=2)

# %%
model = Linear_regression(alpha=0.000001,number_of_iterations=10000)

# %%
model.fit(X_train,Y_train)

# %%
print("Weight is now: ",model.w[0])
print("Bias is now:", model.b)
# Out:
# Weight is now:  3307.388768542075
# Bias is now: -225.74234442346344

# %%
print("Weight is now: ",model.w)
print("Bias is now:", model.b)
# Out:
# Weight is now:  [3307.38876854 2181.56165214]
# Bias is now: -225.74234442346344

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(salary_data['YearsExperience'], salary_data['Age'], salary_data['Salary'], c='red', marker='o')

# Label axes
ax.set_xlabel('Years of Experience')
ax.set_ylabel('Age')
ax.set_zlabel('Salary')

ax.set_title('3D Visualization: Salary vs Experience & Age')

plt.show()

# %%
# Extract values
X_exp = salary_data['YearsExperience']
X_age = salary_data['Age']
Y_salary = salary_data['Salary']

# Your trained model weights
w1 = model.w[0]  # Example weight for YearsExperience
w2 = model.w[1]  # Example weight for Age
b = model.b  # Example bias (intercept)

# Create meshgrid for surface
exp_range = np.linspace(X_exp.min(), X_exp.max(), 20)
age_range = np.linspace(X_age.min(), X_age.max(), 20)
EXP, AGE = np.meshgrid(exp_range, age_range)

# Predict salary using regression equation: z = w1*x + w2*y + b
SALARY = w1 * EXP + w2 * AGE + b

# Plotting
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter points
ax.scatter(X_exp, X_age, Y_salary, color='red', label='Data Points')

# Regression plane
ax.plot_surface(EXP, AGE, SALARY, color='blue', alpha=0.5, label='Regression Plane')

# Labels
ax.set_xlabel('Years of Experience')
ax.set_ylabel('Age')
ax.set_zlabel('Salary')
ax.set_title('Linear Regression: Salary vs Experience and Age')

plt.show()

# %%
plt.scatter(X_test[:, 0], Y_test, color="red")  
plt.plot(X_test[:, 0], model.predict(X_test), color="blue")
plt.show()
plt.scatter(X_test[:, 1], Y_test, color="red")
plt.plot(X_test[:, 1], model.predict(X_test), color="blue")
plt.show()

# %%
# Get predictions
x = X_test[:, 0]
y_pred = model.predict(X_test)

# Sort x and corresponding predictions
sorted_indices = np.argsort(x)
x_sorted = x[sorted_indices]
y_sorted = y_pred[sorted_indices]

# Now plot
plt.scatter(x, Y_test, color="red")
plt.plot(x_sorted, y_sorted, color="blue")
plt.show()
