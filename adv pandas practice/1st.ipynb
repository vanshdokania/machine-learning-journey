# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

# %%
df.head()
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.to_list()
# Out:
# [0, 1, 2]

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'], index=['x','y','z'])

# %%
df.index.to_list()
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "C:/Users/vansh/.kaggle"

# %%
# !kaggle datasets download -d adnanelouardi/600k-fitness-exercise-and-workout-program-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/adnanelouardi/600k-fitness-exercise-and-workout-program-dataset
# License(s): ODbL-1.0
# ...
#   0%|          | 0.00/6.27M [00:00<?, ?B/s]
# 100%|██████████| 6.27M/6.27M [00:00<00:00, 136MB/s]

# %%
fitness_data_set = pd.read_csv(r"D:\ml-linear regression\adv pandas practice\fitness data set\program_summary.csv")

# %%
fitness_data_set.head()
# Out:
#                                                title  \
# 0  (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                         (NOT MY PROGRAM)SHJ Jotaro
# 2  1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                      10 Week Mass Building Program
# 4                             10 week deadlift focus
#
#                                          description  \
# 0  Build tones of muscular with this high intensi...
# 1                            Build strength and size
# 2  Based off of Andy Baker's KCS (Kingwood Streng...
# 3  This workout is designed to increase your musc...
# 4                                  Increase deadlift
#
#                                     level  \
# 0                        ['Intermediate']
# 1            ['Advanced', 'Intermediate']
# 2  ['Beginner', 'Novice', 'Intermediate']
# 3            ['Intermediate', 'Advanced']
# 4            ['Intermediate', 'Advanced']
#
# ...

# %%
fitness_data_set.tail()
# Out:
#                                                 title  \
# 2593                                                🎧
# 2594                                 👾Reza's Routine👾
# 2595  🔥 "Upper Body Dominance: 3-Day Growth System" 🔥
# 2596                                             🙈🙉🙊🐵
# 2597                                              🥷🥷🥷
#
#                                             description  \
# 2593                                         Lihaskasvu
# 2594  This is a beginner friendly routine made for m...
# 2595  "Upper Body Dominance: A science-based 3-day w...
# 2596                             Muscle Memory Training
# 2597        To become stronger without becoming “bulky”
#
#                              level                               goal  \
# 2593  ['Intermediate', 'Advanced']                   ['Bodybuilding']
# 2594  ['Beginner', 'Intermediate']             ['Muscle & Sculpting']
# 2595    ['Intermediate', 'Novice']             ['Muscle & Sculpting']
# ...

# %%
fitness_data_set.sample(15)
# Out:
#                                                title  \
# 918                                    Full body a/b
# 1500                                  Mleccha Slayer
# 1235                       Jared Feather’s Mesocycle
# 156        5-DAY GYM ROUTINE (Lean & Athletic Build)
# 1643                                  Orangutan mode
# 835                                      Farmer Mode
# 639                          Calvin's Crazy Workout!
# 1362                                   Lifter's Work
# 1639  Optimal Silver-Era Lifter - Upper Lower S/Arms
# 655                                   Chat GPT 4 Day
# 1669                                      PPL ARNOLD
# 1517                   Mohit’s Torso and Limbs Split
# 521                                      Black Adder
# 2394                               Upper lower upper
# 2469                                      Winter Ark
#
#                                             description  \
# ...

# %%
fitness_data_set.loc[0]
# Out:
# title               (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# description         Build tones of muscular with this high intensi...
# level                                                ['Intermediate']
# goal                     ['Muscle & Sculpting', 'Bodyweight Fitness']
# equipment                                                    Full Gym
# program_length                                                   12.0
# time_per_workout                                                 90.0
# total_exercises                                                   384
# created                                           2024-01-20 10:23:00
# last_edit                                         2025-06-29 12:39:00
# Name: 0, dtype: object

# %%
fitness_data_set.loc[[3], ['level','total_exercises']]
# Out:
#                           level  total_exercises
# 3  ['Intermediate', 'Advanced']              280

# %%
fitness_data_set.loc[[3]]
# Out:
#                            title  \
# 3  10 Week Mass Building Program
#
#                                          description  \
# 3  This workout is designed to increase your musc...
#
#                           level               goal   equipment  \
# 3  ['Intermediate', 'Advanced']  ['Powerbuilding']  Garage Gym
#
#    program_length  time_per_workout  total_exercises              created  \
# 3            10.0              70.0              280  2024-09-07 03:44:00
#
#              last_edit
# 3  2025-06-18 08:01:00

# %%
fitness_data_set.loc[[3],["goal"]]
# Out:
#                 goal
# 3  ['Powerbuilding']

# %%
fitness_data_set.loc[[3],["goal"]] = ["Vansh Dokania"]

# %%
fitness_data_set.loc[[3],["goal"]]
# Out:
#             goal
# 3  Vansh Dokania

# %%
fitness_data_set.head()
# Out:
#                                                title  \
# 0  (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                         (NOT MY PROGRAM)SHJ Jotaro
# 2  1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                      10 Week Mass Building Program
# 4                             10 week deadlift focus
#
#                                          description  \
# 0  Build tones of muscular with this high intensi...
# 1                            Build strength and size
# 2  Based off of Andy Baker's KCS (Kingwood Streng...
# 3  This workout is designed to increase your musc...
# 4                                  Increase deadlift
#
#                                     level  \
# 0                        ['Intermediate']
# 1            ['Advanced', 'Intermediate']
# 2  ['Beginner', 'Novice', 'Intermediate']
# 3            ['Intermediate', 'Advanced']
# 4            ['Intermediate', 'Advanced']
#
# ...

# %%
fitness_data_set.sort_values("total_exercises")
# Out:
#                                                title  \
# 2461  Wenning Warm-up - Max Effort Squat or Deadlift
# 1872                                          RAVAGE
# 235                                       8 week mog
# 26                                         1RM check
# 1117                    Hometechease workout program
# ...                                              ...
# 2520                               anime revenge arc
# 1240                  Jeff Nippard Body building PPL
# 938                                                G
# 1662                                             PPL
# 2446                                      Webslinger
#
#                                             description  \
# 2461  To warm up, potentiate, engage and activate th...
# 1872                                          cjfjfjfjf
# 235                                            Strength
# 26                                     To find your 1RM
# ...

# %%
fitness_data_set.sort_values("total_exercises", ascending=False)
# Out:
#                                                title  \
# 2446                                      Webslinger
# 1662                                             PPL
# 938                                                G
# 1240                  Jeff Nippard Body building PPL
# 2520                               anime revenge arc
# ...                                              ...
# 1117                    Hometechease workout program
# 26                                         1RM check
# 235                                       8 week mog
# 1872                                          RAVAGE
# 2461  Wenning Warm-up - Max Effort Squat or Deadlift
#
#                                             description  \
# 2446  READ BEFORE TRAINING \n\n\nThis Program provid...
# 1662                                    Muscle Building
# 938                                                   G
# 1240                        Build muscle/ Body Building
# ...

# %%
fitness_data_set.sort_values("program_length", ascending=False)
# Out:
#                                               title  \
# 1379  Low Volume High Intensity Program for Natty's
# 2363           Uncommon Among Most Uncommon Men !!!
# 2364                  Uncommon Among Uncommon Men .
# 286             Advanced GIRLBOSS! HLM 3X Full Body
# 1343                       Legs, push,pull and core
# ...                                             ...
# 2488                         Workout at home (Easy)
# 2493                X-Athlean GYM machine supersets
# 2498                                       Yazheirx
# 1583                                Natty powerlift
# 1349                                           Lera
#
#                                             description  \
# 1379  A classic bodybuilding program focused on buil...
# 2363  This is where we push past our limits ...........
# 2364                   Build strength with hypertrophy.
# 286   The continuation of the Intermediate Girlboss ...
# ...

# %%
fitness_data_set.sort_values("program_length", ascending=False).head()
# Out:
#                                               title  \
# 1379  Low Volume High Intensity Program for Natty's
# 2363           Uncommon Among Most Uncommon Men !!!
# 2364                  Uncommon Among Uncommon Men .
# 286             Advanced GIRLBOSS! HLM 3X Full Body
# 1343                       Legs, push,pull and core
#
#                                             description  \
# 1379  A classic bodybuilding program focused on buil...
# 2363  This is where we push past our limits ...........
# 2364                   Build strength with hypertrophy.
# 286   The continuation of the Intermediate Girlboss ...
# 1343  Designed for beginners through to intermediate...
#
#                                        level  \
# 1379                  ['Beginner', 'Novice']
# 2363              ['Novice', 'Intermediate']
# 2364  ['Intermediate', 'Novice', 'Advanced']
# 286                             ['Beginner']
# 1343                        ['Intermediate']
#
# ...

# %%
for idx,rows in fitness_data_set.iterrows():
    print(idx)
    print(rows['time_per_workout'])
    print('\n\n\n\n\n')
# Out:
# 0
# 90.0
#
#
#
#
#
#
# 1
# 60.0
#
#
#
#
#
#
# 2
# 90.0
#
#
#
#
#
#
# 3
# 70.0
#
#
#
#
#
#
# 4
# 80.0
#
#
#
#
#
#
# 5
# 10.0
#
#
#
#
#
#
# 6
# 60.0
#
#
#
#
#
#
# 7
# 20.0
#
#
#
#
#
#
# 8
# 30.0
#
#
#
#
#
#
# 9
# 60.0
#
#
#
#
#
#
# 10
# 40.0
#
#
#
#
#
#
# 11
# 60.0
#
#
#
#
#
#
# 12
# 70.0
#
#
#
#
#
#
# 13
# 60.0
#
#
#
#
#
#
# 14
# 70.0
#
#
#
#
#
#
# 15
# 90.0
#
#
#
#
#
#
# 16
# 60.0
#
#
#
#
#
#
# 17
# 180.0
#
#
#
#
#
#
# 18
# 60.0
#
#
#
#
#
#
# 19
# 100.0
#
#
#
#
#
#
# 20
# 90.0
#
#
#
#
#
#
# 21
# 30.0
#
#
#
#
#
#
# 22
# 90.0
#
#
#
#
#
#
# 23
# 20.0
#
#
#
#
#
#
# 24
# 60.0
#
#
#
#
#
#
# 25
# 70.0
#
#
#
#
#
#
# 26
# 40.0
#
#
#
#
#
#
# 27
# 70.0
#
#
#
#
#
#
# 28
# 30.0
#
#
#
#
#
#
# 29
# 60.0
#
#
#
#
#
#
# 30
# 60.0
#
#
#
#
#
#
# 31
# 60.0
#
#
#
#
#
#
# 32
# 70.0
#
#
#
#
#
#
# 33
# 90.0
#
#
#
#
#
#
# 34
# 70.0
#
#
#
#
#
#
# 35
# 120.0
#
#
#
#
#
#
# 36
# 180.0
#
#
#
#
#
#
# 37
# 120.0
#
#
#
#
#
#
# 38
# 80.0
#
#
#
#
#
#
# 39
# 60.0
#
#
#
#
#
#
# 40
# 70.0
#
#
#
#
#
#
# 41
# 90.0
#
#
#
#
# ...

# %%
programLength = fitness_data_set.sort_values("program_length")
for idx,rows in programLength.iterrows():
    print(idx)
    print(rows['program_length'])
    print('\n\n\n\n\n')
# Out:
# 1935
# 1.0
#
#
#
#
#
#
# 1480
# 1.0
#
#
#
#
#
#
# 1481
# 1.0
#
#
#
#
#
#
# 1494
# 1.0
#
#
#
#
#
#
# 1800
# 1.0
#
#
#
#
#
#
# 1149
# 1.0
#
#
#
#
#
#
# 2522
# 1.0
#
#
#
#
#
#
# 76
# 1.0
#
#
#
#
#
#
# 725
# 1.0
#
#
#
#
#
#
# 717
# 1.0
#
#
#
#
#
#
# 707
# 1.0
#
#
#
#
#
#
# 712
# 1.0
#
#
#
#
#
#
# 734
# 1.0
#
#
#
#
#
#
# 1094
# 1.0
#
#
#
#
#
#
# 1850
# 1.0
#
#
#
#
#
#
# 1831
# 1.0
#
#
#
#
#
#
# 749
# 1.0
#
#
#
#
#
#
# 754
# 1.0
#
#
#
#
#
#
# 2187
# 1.0
#
#
#
#
#
#
# 1181
# 1.0
#
#
#
#
#
#
# 647
# 1.0
#
#
#
#
#
#
# 663
# 1.0
#
#
#
#
#
#
# 1117
# 1.0
#
#
#
#
#
#
# 1099
# 1.0
#
#
#
#
#
#
# 587
# 1.0
#
#
#
#
#
#
# 586
# 1.0
#
#
#
#
#
#
# 588
# 1.0
#
#
#
#
#
#
# 2201
# 1.0
#
#
#
#
#
#
# 165
# 1.0
#
#
#
#
#
#
# 2498
# 1.0
#
#
#
#
#
#
# 2493
# 1.0
#
#
#
#
#
#
# 2488
# 1.0
#
#
#
#
#
#
# 444
# 1.0
#
#
#
#
#
#
# 1637
# 1.0
#
#
#
#
#
#
# 375
# 1.0
#
#
#
#
#
#
# 2292
# 1.0
#
#
#
#
#
#
# 2272
# 1.0
#
#
#
#
#
#
# 1793
# 1.0
#
#
#
#
#
#
# 560
# 1.0
#
#
#
#
#
#
# 578
# 1.0
#
#
#
#
#
#
# 1751
# 1.0
#
#
#
# ...

# %%
fitness_data_set.head()
# Out:
#                                                title  \
# 0  (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                         (NOT MY PROGRAM)SHJ Jotaro
# 2  1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                      10 Week Mass Building Program
# 4                             10 week deadlift focus
#
#                                          description  \
# 0  Build tones of muscular with this high intensi...
# 1                            Build strength and size
# 2  Based off of Andy Baker's KCS (Kingwood Streng...
# 3  This workout is designed to increase your musc...
# 4                                  Increase deadlift
#
#                                     level  \
# 0                        ['Intermediate']
# 1            ['Advanced', 'Intermediate']
# 2  ['Beginner', 'Novice', 'Intermediate']
# 3            ['Intermediate', 'Advanced']
# 4            ['Intermediate', 'Advanced']
#
# ...

# %%
fitness_data_set.loc[[3],["goal"]] = "updated using loc"

# %%
fitness_data_set.head()
# Out:
#                                                title  \
# 0  (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                         (NOT MY PROGRAM)SHJ Jotaro
# 2  1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                      10 Week Mass Building Program
# 4                             10 week deadlift focus
#
#                                          description  \
# 0  Build tones of muscular with this high intensi...
# 1                            Build strength and size
# 2  Based off of Andy Baker's KCS (Kingwood Streng...
# 3  This workout is designed to increase your musc...
# 4                                  Increase deadlift
#
#                                     level  \
# 0                        ['Intermediate']
# 1            ['Advanced', 'Intermediate']
# 2  ['Beginner', 'Novice', 'Intermediate']
# 3            ['Intermediate', 'Advanced']
# 4            ['Intermediate', 'Advanced']
#
# ...

# %%
fitness_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             2598 non-null   object
#  1   description       2594 non-null   object
#  2   level             2598 non-null   object
#  3   goal              2598 non-null   object
#  4   equipment         2597 non-null   object
#  5   program_length    2597 non-null   float64
#  6   time_per_workout  2598 non-null   float64
#  7   total_exercises   2598 non-null   int64
#  8   created           2597 non-null   object
#  9   last_edit         2596 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 203.1+ KB

# %%
fitness_data_set.loc[fitness_data_set['program_length']>10]['program_length']
# Out:
# 0       12.0
# 6       12.0
# 7       12.0
# 9       12.0
# 10      12.0
#         ...
# 2585    12.0
# 2587    12.0
# 2591    12.0
# 2592    12.0
# 2593    12.0
# Name: program_length, Length: 1065, dtype: float64

# %%
fitness_data_set.loc[fitness_data_set['program_length']>10]['program_length'].sample(5)
# Out:
# 1057    12.0
# 889     12.0
# 2538    18.0
# 56      12.0
# 1568    16.0
# Name: program_length, dtype: float64
